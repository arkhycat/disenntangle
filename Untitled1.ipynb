# %%
import torch
import torchvision

from col_mnist import ColMNIST
trainloader = torch.utils.data.DataLoader(
  ColMNIST('data/mnist', train=True, download=True,
                             transform=torchvision.transforms.Compose([#torchvision.transforms.Resize((224, 224)),
                               torchvision.transforms.ToTensor(),
                             ]), only_frame = True),
  batch_size=32, shuffle=True)

# %%
from plotting_utils import show_dataset_examples
show_dataset_examples(trainloader)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_499/1725894125.py in <module>
#       1 from plotting_utils import show_dataset_examples
# ----> 2 show_dataset_examples(trainloader)
#
# /diseNN/plotting_utils.py in show_dataset_examples(trainer)
#      17         plt.show()
#      18
# ---> 19     dataiter = iter(trainer.test_loader)
#      20     images, labels = dataiter.next()
#      21     imshow(torchvision.utils.make_grid(images))
#
# AttributeError: 'DataLoader' object has no attribute 'test_loader'

# %%
import matplotlib.pyplot as plt
import numpy as np
def imshow(img):
    #img = img / 2 + 0.5     # unnormalize
    npimg = img.cpu().numpy()
    plt.rcParams['xtick.bottom'] = False
    plt.rcParams['xtick.labelbottom'] = False
    plt.rcParams['ytick.left'] = False
    plt.rcParams['ytick.labelleft'] = False
    plt.imshow(np.transpose(npimg, (1, 2, 0)))
    plt.show()

dataiter = iter(trainloader)
images, labels = dataiter.next()
imshow(torchvision.utils.make_grid(images))
img_shape = images[0].shape
print("Image shape: {}".format(img_shape))
# Out:
# Image shape: torch.Size([3, 36, 36])
